# %%
import numpy as np
from scipy.stats import rv_discrete
from matplotlib import pyplot as plt
import cvxpy as cp
import pickle
# import gurobipy

# %%
def average_paths(Cost_paths, Queue_paths, fract = 0, plot = 0):
    Queue_paths = np.transpose( np.asarray(Queue_paths) )
    Cost_paths = np.transpose( np.asarray(Cost_paths) )
    time_steps = len(Queue_paths[0])
    average_queue_lengths = np.average(Queue_paths[int(time_steps*fract):,:], axis = 0)
    average_cost = np.average(Cost_paths[int(time_steps*fract):,:], axis=0)
    if plot:
        plt.plot(average_queue_lengths,average_cost,'x')
        plt.show()
    return(average_cost,average_queue_lengths)

def plot_from_sim_paths(file_name, frac = 0):
    with open(file_name,'rb') as f:
        Qpaths,Cpaths = pickle.load(f)
    # Q_paths_M = M_res["Q_paths"]
    # C_paths_M = M_res["C_paths"]
    # Q_paths_B = B_res["Q_paths"]
    # C_paths_B = B_res["C_paths"]
    Q_paths_B = Qpaths
    C_paths_B = Cpaths
    # (average_cost_M, average_queue_M) = average_paths(C_paths_M,Q_paths_M, frac)
    (average_cost_B, average_queue_B) = average_paths(C_paths_B,Q_paths_B, frac)
    plt.figure( figsize=(10,6) ) 
    
    # C = 0 Case
    
    # C = Inf/Fluid Case
    # ylim = max( max( average_queue_B ), max( average_queue_M ) )
    
    # plt.plot([fluid_sol['Cost'],fluid_sol['Cost']],[0,ylim],linewidth = 3)
    # Batching data
    plt.plot(average_cost_B,average_queue_B,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
    # Max Weight data
    # plt.plot(average_cost_M, average_queue_M,'go',markersize = 8)
    # plt.plot([Ex],[1],'r*',markersize = 12, markeredgewidth=3)
    plt.ylabel("Average queue length", weight='bold',fontsize=12)
    plt.xlabel("Average cost", weight='bold',fontsize=12)
    plt.title("c vs q", weight='bold',fontsize=15)
    # plt.legend(['Fluid', 'Batching', 'Max-weight', 'c = 0 sol'])
    # plt.legend([ 'Batching', 'Max-weight', 'c = 0 sol'])
    plt.grid(True)

# %%
file_name = "../../batch-new.pkl"
plot_from_sim_paths(file_name)

# %%
len([[0,1],[0,1],[0,1]])
# Out:
# 3

# %%
with open(file_name,'rb') as f:
        Qpaths,Cpaths = pickle.load(f)

# %%
Qpaths = np.asarray(Qpaths)
Qpaths.shape
# Out:
# (16, 100000)

# %%
np.sum( Qpaths[0] == Qpaths[10] )
# Out:
# 100000

# %%
with open("batch-test.pkl",'rb') as f:
        Qpaths,Cpaths = pickle.load(f)
Qpaths = np.asarray(Qpaths)
Qpaths.shape
# Out:
# (16, 100)

# %%
np.average(Qpaths,1)
# Out:
# array([ 1.  ,  1.5 ,  1.99,  2.5 ,  3.  ,  4.42,  5.5 ,  6.34,  7.75,
#         9.1 , 10.5 , 14.5 , 18.5 , 25.5 , 26.5 , 50.5 ])

# %%
with open("../../batch.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)
    
Q_paths_B = Qpaths
C_paths_B = Cpaths

with open("../../batch-2-small.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)

Q_paths_B = Q_paths_B + Qpaths
C_paths_B = C_paths_B + Cpaths
(average_cost_B, average_queue_B) = average_paths(C_paths_B,Q_paths_B)
plt.figure( figsize=(10,6) ) 

# C = 0 Case

# C = Inf/Fluid Case
# ylim = max( max( average_queue_B ), max( average_queue_M ) )

# plt.plot([fluid_sol['Cost'],fluid_sol['Cost']],[0,ylim],linewidth = 3)
# Batching data
plt.plot(average_cost_B,average_queue_B,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
# Max Weight data
# plt.plot(average_cost_M, average_queue_M,'go',markersize = 8)
# plt.plot([Ex],[1],'r*',markersize = 12, markeredgewidth=3)
plt.ylabel("Average queue length", weight='bold',fontsize=12)
plt.xlabel("Average cost", weight='bold',fontsize=12)
plt.title("c vs q", weight='bold',fontsize=15)
# plt.legend(['Fluid', 'Batching', 'Max-weight', 'c = 0 sol'])
# plt.legend([ 'Batching', 'Max-weight', 'c = 0 sol'])
plt.grid(True)

# %%
C_paths_B = np.asarray(C_paths_B)
C_paths_B.shape
# Out:
# (19, 100000)

# %%
f = [[1,2,3],[4,5,6]]
f += [[7,8,9]]

# %%
average_queue_B
# Out:
# array([  1.99999,   1.99999,   1.99999,   1.99999,   1.99999,   1.99999,
#          1.99999,   1.99999,   1.99999,   1.99999,   1.99999,   1.99999,
#          1.99999,   1.99999,   1.99999,   1.99999,  75.475  , 100.5    ,
#        125.5    ])

# %%
with open("../../batch-new.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)
with open("../../batch.pkl",'rb') as f:
    Qpaths2, Cpaths2 = pickle.load(f)

# %%
Qpaths = np.asarray(Qpaths)
Qpaths.shape
# Out:
# (15, 100000)

# %%
with open("../../batch.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)
    
Q_paths_B = Qpaths
C_paths_B = Cpaths

with open("../../batch-new.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)

Q_paths_B = Q_paths_B + Qpaths
C_paths_B = C_paths_B + Cpaths
(average_cost_B, average_queue_B) = average_paths(C_paths_B,Q_paths_B)
plt.figure( figsize=(10,6) ) 

# C = 0 Case

# C = Inf/Fluid Case
# ylim = max( max( average_queue_B ), max( average_queue_M ) )

# plt.plot([fluid_sol['Cost'],fluid_sol['Cost']],[0,ylim],linewidth = 3)
# Batching data
plt.plot(average_cost_B,average_queue_B,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
# Max Weight data
# plt.plot(average_cost_M, average_queue_M,'go',markersize = 8)
# plt.plot([Ex],[1],'r*',markersize = 12, markeredgewidth=3)
plt.ylabel("Average queue length", weight='bold',fontsize=12)
plt.xlabel("Average cost", weight='bold',fontsize=12)
plt.title("c vs q", weight='bold',fontsize=15)
# plt.legend(['Fluid', 'Batching', 'Max-weight', 'c = 0 sol'])
# plt.legend([ 'Batching', 'Max-weight', 'c = 0 sol'])
plt.grid(True)

# %%
# Get the sorted indices of x
sorted_indices = np.argsort(average_cost_B)

# Sort x and reorder y accordingly
average_cost_B = average_cost_B[sorted_indices]
average_queue_B = average_queue_B[sorted_indices]

# %%
plt.plot(np.log(average_cost_B),np.log(average_queue_B),'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")

# %%
# Polynomial fit
deg = 1
xB = np.log(average_cost_B)
yB = np.log(average_queue_B)




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel(r"$log(\bar{q})$", weight='bold',fontsize=15)
plt.xlabel(r"$log(\bar{c}-c^*)$", weight='bold',fontsize=15)
plt.title("Log-Log Plot", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-2.2660129   0.20340053] [0.0795699]

# %%
import numpy as np
Tbatches = np.arange(2400, 100000, 5000)

# %%
Tbatches = np.append(Tbatches,99999)

# %%
Tbatches
# Out:
# array([  2400,   7400,  12400,  17400,  22400,  27400,  32400,  37400,
#         42400,  47400,  52400,  57400,  62400,  67400,  72400,  77400,
#         82400,  87400,  92400,  97400, 100000,  99999])

# %%
plt.plot(np.log(average_cost_B[:15]),np.log(average_queue_B[:15]),'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")

# %%
# Polynomial fit
deg = 1
xB = np.log(average_cost_B[:15])
yB = np.log(average_queue_B[:15])




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel(r"$log(\bar{q})$", weight='bold',fontsize=15)
plt.xlabel(r"$log(\bar{c}-c^*)$", weight='bold',fontsize=15)
plt.title("Log-Log Plot", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-2.16543888  0.47507088] [0.01603899]

# %%
# Polynomial fit
deg = 1
xB = np.log(average_cost_B[:10])
yB = np.log(average_queue_B[:10])




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel(r"$log(\bar{q})$", weight='bold',fontsize=15)
plt.xlabel(r"$log(\bar{c}-c^*)$", weight='bold',fontsize=15)
plt.title("Log-Log Plot", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-2.0160129   0.91879769] [0.00631722]

# %%
len(average_cost_B)
# Out:
# 31

# %%
with open("../../batch.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)
    
Q_paths_B = Qpaths
C_paths_B = Cpaths

with open("../../batch-new.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)
Q_paths_B = Q_paths_B + Qpaths
C_paths_B = C_paths_B + Cpaths

with open("../../batch-more.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)

Q_paths_B = Q_paths_B + Qpaths
C_paths_B = C_paths_B + Cpaths

# %%
len(Qpaths)
# Out:
# 10

# %%
(average_cost_B, average_queue_B) = average_paths(C_paths_B,Q_paths_B)
plt.figure( figsize=(10,6) ) 

# C = 0 Case

# C = Inf/Fluid Case
# ylim = max( max( average_queue_B ), max( average_queue_M ) )

# plt.plot([fluid_sol['Cost'],fluid_sol['Cost']],[0,ylim],linewidth = 3)
# Batching data
plt.plot(average_cost_B,average_queue_B,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
# Max Weight data
# plt.plot(average_cost_M, average_queue_M,'go',markersize = 8)
# plt.plot([Ex],[1],'r*',markersize = 12, markeredgewidth=3)
plt.ylabel("Average queue length", weight='bold',fontsize=12)
plt.xlabel("Average cost", weight='bold',fontsize=12)
plt.title("c vs q", weight='bold',fontsize=15)
# plt.legend(['Fluid', 'Batching', 'Max-weight', 'c = 0 sol'])
# plt.legend([ 'Batching', 'Max-weight', 'c = 0 sol'])
plt.grid(True)

# %%
# Get the sorted indices of x
sorted_indices = np.argsort(average_cost_B)

# Sort x and reorder y accordingly
average_cost_B = average_cost_B[sorted_indices]
average_queue_B = average_queue_B[sorted_indices]

# %%
# Polynomial fit
deg = 1
xB = np.log(average_cost_B)
yB = np.log(average_queue_B)




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel("Average queue length", weight='bold',fontsize=12)
plt.xlabel("Average cost", weight='bold',fontsize=12)
plt.title("c vs q", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-2.24696639  0.22340426] [0.15488806]

# %%
# Polynomial fit
deg = 1
xB = np.log(average_cost_B[:20])
yB = np.log(average_queue_B[:20])




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel(r"$log(\bar{q})$", weight='bold',fontsize=15)
plt.xlabel(r"$log(\bar{c}-c^*)$", weight='bold',fontsize=15)
plt.title("Log-Log Plot", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-2.02867426  0.8928335 ] [0.03003868]

# %% [markdown]
# ## 3D

# %%
file_name = "../../batch-new-3D.pkl"
plot_from_sim_paths(file_name)

# %%
# Polynomial fit
with open("../../batch-new-3D.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)
    
Q_paths_B = Qpaths
C_paths_B = Cpaths

# with open("../../batch-new.pkl",'rb') as f:
#     Qpaths,Cpaths = pickle.load(f)

# Q_paths_B = Q_paths_B + Qpaths
# C_paths_B = C_paths_B + Cpaths
(average_cost_B, average_queue_B) = average_paths(C_paths_B,Q_paths_B)
plt.figure( figsize=(10,6) ) 

deg = 1
xB = np.log(average_cost_B)
yB = np.log(average_queue_B)




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel("Average queue length", weight='bold',fontsize=12)
plt.xlabel("Average cost", weight='bold',fontsize=12)
plt.title("c vs q", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-2.90687828  0.8883381 ] [0.02935559]

# %%
# Get the sorted indices of x
sorted_indices = np.argsort(average_cost_B)

# Sort x and reorder y accordingly
average_cost_B = average_cost_B[sorted_indices]
average_queue_B = average_queue_B[sorted_indices]

# %%
# Polynomial fit
deg = 1
xB = np.log(average_cost_B[:15])
yB = np.log(average_queue_B[:15])




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel("Average queue length", weight='bold',fontsize=12)
plt.xlabel("Average cost", weight='bold',fontsize=12)
plt.title("c vs q", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-2.84392957  1.00359096] [0.00281535]

# %%
# Polynomial fit
with open("../../batch-new-3D.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)
    
Q_paths_B = Qpaths
C_paths_B = Cpaths

with open("../../batch-new-3D-2.pkl",'rb') as f:
    Qpaths,Cpaths = pickle.load(f)

Q_paths_B = Q_paths_B + Qpaths
C_paths_B = C_paths_B + Cpaths
(average_cost_B, average_queue_B) = average_paths(C_paths_B,Q_paths_B)

plt.figure( figsize=(10,6) ) 
    
# C = 0 Case

# C = Inf/Fluid Case
# ylim = max( max( average_queue_B ), max( average_queue_M ) )

# plt.plot([fluid_sol['Cost'],fluid_sol['Cost']],[0,ylim],linewidth = 3)
# Batching data
plt.plot(average_cost_B,average_queue_B,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
# Max Weight data
# plt.plot(average_cost_M, average_queue_M,'go',markersize = 8)
# plt.plot([Ex],[1],'r*',markersize = 12, markeredgewidth=3)
plt.ylabel("Average queue length", weight='bold',fontsize=12)
plt.xlabel("Average cost", weight='bold',fontsize=12)
plt.title("c vs q", weight='bold',fontsize=15)
# plt.legend(['Fluid', 'Batching', 'Max-weight', 'c = 0 sol'])
# plt.legend([ 'Batching', 'Max-weight', 'c = 0 sol'])
plt.grid(True)

# %%
plt.figure( figsize=(10,6) ) 

deg = 1
xB = np.log(average_cost_B)
yB = np.log(average_queue_B)




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel("Average queue length", weight='bold',fontsize=12)
plt.xlabel("Average cost", weight='bold',fontsize=12)
plt.title("c vs q", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-2.87855326  0.9050335 ] [0.09159304]

# %%
# Polynomial fit
deg = 1
xB = np.log(average_cost_B[:15])
yB = np.log(average_queue_B[:15])




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel(r"$log(\bar{q})$", weight='bold',fontsize=15)
plt.xlabel(r"$log(\bar{c}-c^*)$", weight='bold',fontsize=15)
plt.title("Log-Log Plot", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-3.01049785  0.85861112] [0.00234035]

# %%
# Polynomial fit
deg = 1
xB = np.log(average_cost_B[:20])
yB = np.log(average_queue_B[:20])




plt.figure( figsize=(10,6) )
plt.plot(xB, yB,'x',markersize = 10, markeredgewidth=3, markeredgecolor="darkblue")
pB, resB, _, _, _ = np.polyfit(xB, yB, 1, full=True)
print(pB,resB)
predict2 = np.poly1d(pB)
x  = np.array(xB)
y = predict2(x)
plt.plot(x, y,'r')
plt.ylabel("Average queue length", weight='bold',fontsize=12)
plt.xlabel("Average cost", weight='bold',fontsize=12)
plt.title("c vs q", weight='bold',fontsize=15)
plt.legend(["Batching points",str(round(predict2[1],2))+"x + " + str(round(predict2[0],2)),])
plt.grid(True)
# Out:
# [-2.94259749  0.87485125] [0.01416725]
